# %%
# Importing Libraries
import pytesseract
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('1.png')
cv2.imshow('sample image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %% [markdown]
# ## Text Recognition

# %%
img2 = pytesseract.image_to_string(img)
print(img2)
# Out:
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format.
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox.

# %% [markdown]
# ## Handwriting Recognition

# %%
imge = cv2.imread('de.jpg')
cv2.imshow('sample image',imge)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(imge)

# %%
img3 = pytesseract.image_to_string(imge)
print(img3)
# Out:
# Me\biy\
# M aoti”

# %%
imge = cv2.imread('d.jpg')
plt.imshow(imge)

# %%
img4 = pytesseract.image_to_string(imge)
print(img4)
# Out:
# MELBIN
# MART |N

# %%
img = cv2.imread('d2.jpg')
plt.imshow(img)

# %%
img5 = pytesseract.image_to_string(img)
print(img5)
# Out:
# MELB\N
# MART

# %%
img = cv2.imread('d3.jpg')
plt.imshow(img)

# %%
img6 = pytesseract.image_to_string(img)
print(img6)
# Out:
# Melbiv\

# %%
img = cv2.imread('df.png')
plt.imshow(img)

# %%
img7 = pytesseract.image_to_string(img)
print(img7)
# Out:
#
#
# Siwy Thomas
#
#
#
#
#
# See) Vyluack
#
#
#
# ktm __TAvLoR
#
#
#
# bor) Dans
#
#
#
# RES iby | BG ek
#
# Wendy fleck

# %%
img = cv2.imread('h1.png')
plt.imshow(img)

# %%
img8 = pytesseract.image_to_string(img)
print(img8)
# Out:
# This is a handwritten
# example
#
# Write as qooal as you can.

# %%
img = cv2.imread('fg.png')
plt.imshow(img)

# %%
img9 = pytesseract.image_to_string(img)
print(img9)
# Out:
# SS RELIGARE i Health
#
# Values that bind Insur. ance
#
# Claim Form - ‘GROUP CARE’
# Part A
#
# |. Tobe filled in by the Insured.
# 2. Theissue of this Formisnotte be taken as an admissicn of liability.
# 3. Tobe filled inblock letters.
#
# " Section A - Details of Primary Insured
#
#
#
# Abo Health Hamesha
#
#
#
# a) PolcyNo : (IBL</D/ EI Fla[ Hi
#
#
#
#
#
# b) SLNoJCertificate No: [%
#
#
#
# d) Name :| |
#
#
#
#
#
#
#
# e) Address
