# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('12.jpg')
# cv2.imshow('sample image',image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
plt.imshow(image)

# %%
gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)

# %%
# plt.imshow(gray)
# plt.imshow(thresh)
# plt.imshow(opening)
# plt.imshow(canny)

# %%
img2 = pytesseract.image_to_string(image)
print(img2)
# Out:
#
#
# SBI General Insurance Company Limited $B iGeneral
# 190546 | UIN S8G-MO-P12-57-V02-11-12
# IRDAL of india Reg No 144 dared 15/12/2009 | CIN U66000MH2009PLC | a
# PRIVATE CAR/TWO WHEELER INSURANCE POLICY Call (Toll Free) 1800 22 1111 | 1800 102 mn
# fed} wea Wa www.sbigeneral. in/download W Sac é| , aed Seas
# ckage
#
# Proposal Form :
#
# Tho queres stated bolow are minimum requirement to be furnished by @ Proposer The insurer may seek moro information as desired for underwriting purpose
#
# []eucer [77 two Wrecler Propasaltor: (|New [_] Renewal [ ] Rotover [_] used [_] Endorsement To.be filed in BLOCK LETTERS ONLY
#
# a eee
# proposaino. (3/2 11 al tine LI aeee |_| rocoto [TT TT TT) cose AAS BABE!
# |
#
# TREAD
# owen. = [| J 1] c ee fs IE IE) irere Beseeene
# cae lal 44 (eee eels - LT J [_] Recetot to FE Reece ]o ry.
# LI
#
#
#
#
#
#
#
#
#
#
#
# pars. PEGE TT ELLLLE LLL store KERALA SP Cone
#
# fe roki Direct
# Business Sector [~ ] Urban ae [| Social GSTINASDN [WAPPLICABLE _| Customer Segment [] Aaency [__] Banca [] CorporatesBroking [_]
#
# you on with SBI General Insurance then please provide Customer ID / Policy number : Les fa ee bayer om ag ee ee
# me = [] ] [) Name PMTCT BE VIM TD IMMA TRIN [eT ToT EEE lel Liao 1d
# Gender 7 mate [] Female [=] Third Gender Date of Birth Pola AlUg Contact No. (a2Alpsieia gic! | 1)
# emo [ASIC a hol A Tel elo TTT TT TTT Mobile No L
# commmatene ARIEL DEEEEEEL EET
#
# DOB of Proposer [o [io MIM y
#
#
#
# 29 | fee |
# ia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# panino (STATI eto +
#
# Address ot House No. [FID | T iseleal [] Bock (ATA CA | |} Bulsing
#
# the Proposer ams! L a sss (Kola HAIN [1 1 J
#
# se (RAAB CEE) oe RISA SIG) comm [Leo L11 4
#
# RISK COVERAGE DETAILS Ne on Expiring %
#
# Period of Insurance: From | +4] r BE) mab TE ‘1¥] til midnight of | 0 | 0 | JM cE ly e Ly
#
# Previous Year Polcy Period GE cy} wf aie VLD Te] Boingo =) [N) tscayeas co poo
#
# Previous Policy No. be TH l isle) he Insurer
#
# pede | SEI | aE ithin
#
# Usage of Vehicle L] Business (a aie Driver = Driver's Driving Expenence a) Parking Type (a Garage fs] Public Street Compound
#
# Date of Registration §— | | 0 |i ts |¥ |v | EG [fo] a [| a FO [i] |e car
#
# i d
# Vehicle Make, Model & Variant | Month & Year of Mig. | Registration Number Engine Number Chassis Number ) Seating Capacity, CC
# ee a fee z | ae:
#
# Vehicle Insured Declared Value RS Electrical Non-Electrical Trailer Value As. | Side Car Value Rs. | [_] cnG/[_] LPGKit As. Total IDV Rs.
# Accessories Rs Accessories Rs. (Two wheeler) (not provided by manufacturers)
#
#
#
# ee
#
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FH
# a
# al
# a
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# at
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A B Cc: 0 E A+B+C+D0+E+
# (SES |
#
# Vehicle modification (3 Yes | No Ht Yes, provide details
#
# [__} vega! Uabitty to Pate Orver Se ee eee [__] PAto Unnamed Passenger Sum Insured Rs, __
#
#
#
# Nominee Details: Name i 5 aoe Topas Relation
# intee Relatio (Se ae ee eel
# (Nomine finn) ) ai] ) TTT TT TT 1) trtre nominee
#
# ADD-ON COVER DETAILS
#
#
#
#
#
#
#
#
#
#
#
#
#
# Re Depreciation Reimbursement (Pvt Car Only) C] Cover for Consumables (Pvt Car only) = Engine guard (Pvt Car only) C] Return To Invoice
#
# EI Protecton of NCB (Cover available to protect NCB upto 50% Only as per eligibility) C] Basic road side assistance (Pvt Car only) ial Additional road side assistance (Pvt Car only)
#
# {_] Loss of Personal Belongings (Pvt Car Only) Rs, ———_____ [__] Cover for Key Replacement (Pvt Car only) [_ ] inconvenience Allowance (Pvt Car Only) Rs.
#
# (is) Enhance PA Cover for insured (Owmer Driver) / unnamed passengers / Paid Drivers (Pvt Car only) sum Insured per person Rs,
#
# a Hospital Cash Cover for Insured (Owner Driver) / unnamed passengers / Paid Drivers (Pvt Car onty) RS|/§ — aaa i iii i & EMI Protector (Private car only)
# fi HYPOTHECATION es it es GB LEASE PURCHASE
#
# Name of Financial Institution [ ale eet
#
#
#
#
#
#
#
#
# 0 Gee se Cees e meee tonaccunvvo (ET PTT TTT ELL
# INSURED'S DECLARED VALUE (IDV) OF THE VEHICLE
# The IDV of the vehicle will be deemed Io be the sum insured for the purpose of the poli
#
#
#
#
#
# & will be fixed on the basis of the manufacturers listed setling
#
#
#
#
# price of the brand and adjusted for Depreciation as per schedule below
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Age olthe Vehicle % of Depreciation
# ee St 30%
# Exceeding 1 year but not exceeding 2 years 20% Exceeding 4 years but nol exceeding 5 years
# VOLUNTARY DEDUCTIBLE
# Standard minimum deductible is Rs, 100/- for two wheelers, Rs. 1000 for private cars with CC upto 1500 & As. 2000/- for private cars above 1500 cc from each and every claim
# PRIVATE CAR DEDUCTIBLE TWO WHEELER
#
# Std min deductible Pius
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Rs_ 2500 [_J Std min deductible Plus _
# J Stdmin deductible Plus SSS [| Std min deductible Pus
# | Std min deductible Plus Rs. 7500 | sta min deductible Plus
#
#
#
#
#
# Std min Geductible Plus
#
#
#
#
#
# me Bs s12000;
#
# | |_| Std min deductible Plus
# | _| Std min deductible Pius
#
# Corporate & Registered Ollice ‘Natyaj , 301, Junction of Western Express Highway & Andheri - Kurla Road. Andheri (East), Mumbai - 400 069.
#
#
#
# int December 2016 2.0
#
# Version No 2.0, December 2018 | Pri

# %%
img2 = pytesseract.image_to_string(canny)
print(img2)
# Out:
#
#
# $81 Generel Invuranes Company Lemtled
#
# (ROA) of tnaik Req Np 1d daierd USI 22EO9 | Cin USECCOM
#
# PRIVATE CAR/TWO WHIEELER | INSURANCE POLICY |
# TAR Sta www.sblgeneral.indownload & SITET G |
#
# Proposal Form
#
# FIZCOPPLE19OSAG §
#
# UN). SOG-MO-P]QS7VG2- | |-12
#
# PPB euenel
#
# eee Sa
#
#
#
#
#
#
#
#
#
#
#
#
#
# Call (Tali Free) 1800 22 1111 a 1860 Toz 1109
#
# mrw.soigsacral.in
#
# a wee
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tho cuerles sland below ore minimunn requirement (o be hye shed by 0 Prepaset_tihe vend fe] atom | uae tes endenuatting parpars
# | ewee Mie Fraposslter: [_] tow resent [L_] Bano) vee Endemenent Too filled ta BLOCH LETTERS ONLY
# (ROR OFRIEE Wise, ~ j
# Lr) wee CPTI) @@ COCeOo
# mee BR EECCCCCLEC LD ser COCA Se COP
# oun, [] | | | | [| LI al Coca anne ===
# snare i, LLLLLCELELELI [_[_]_) Peceinnwe, [| Ll Recolpt ate (efols eae dy
# om. CCLIIILILLELL ELIE LLL soe KERALA  %ee (TTI E |
# Qusthess Sector [| Urban (_) pra C4} Social  — GSTINASDN (_wreruceat | Customer Seganeat DD Agency Banga CorparatefDraliag ‘a Oleeet
# [PROPOSES i Se — : ——
# if you have esting relsdanship wth SOI General Insurance then please provide Customar 10 ) Pally umber ¢ L | a i . |__J a)
# Tile COLL) «re MERSIN TR aLw l [ofels mee A wv fala talwfel | J
# Gender (A toate C] Female ‘- Third Gender Oats ot Git» (| BH POLL Ae QB] Contact No. “S| Zl isc) VARIG U |)
# oo [eam an A leer (I ae wt | LITT ET yt
# Gcoupstion of hones = RS TEI LLL me LJ |
# ol Prepaser on pulaly [ye pasa io. OIA TE 24) Bereta Jt
# astress of Howselte. [EF | | aie (ATG CLI | 1 | | Suesting | | J
# Prope = = —— i
# a T 1 set [| | J] whkekhl4nsa Md
# om (Kae LLL Z Pneate [ZS ) com (1 TaPol oT 4
# Comorian «Yes (nto] «= L_ |e Tianiso f APPLICABLE a ;
# (_ ESiciemrnatiC A Se eo
# " ,
# Paid ol insoronce From = [x[ HL | 83) 2! (0 [0 Ps Joo [x [v [v [9] * a mbéod alo vy ay i ULI *
# predeus tear Paty orice (Ja [ale |v Dy] (0 fe lslw]y ly {el} ] Bon o ac my ae
# es Paley So, | | | | | |_| Presa ingurer _! | | Li L
# deres
# Prous ae | i Lt | — LI | LI — LI ae LI (ie tain
# Usage of Vehicle | Gusiness = || Palate Brover Age [2.1 3} Oriver’s Driving Expenence | | | Patang Tyee [_ | Garage O Pubic Steet [| Compound
# Dae etRegisiaion (Ole) jalviviviy] 9 a LL] TLL TL) @LLei ean | | Jt
# Wentcle Mate, Rodel 8 Varant | Scr Registration Plumber Engine Somber Chassis Humber [ Seating Cagectry | cc_| Fuelllsed
# [  Vetdete insured Oeclarad Value is, Gectical |  Non-Elecwical ‘Tedller Value As, ide Car Value Rs. | (_] ere (_] Wer Rs. Total (OY Fis.
# 5 Accessorles Rs, Accessonas Rs. (leo wheeler) (not provided by manuiaciurars)
# @_ \ { © © L. (0) ©. Gl (As0+C+0+E +6)
# i LI = i
# Wieln Glenanocitcrato) 0D ‘Yes = 0) i Yes, pravida datalls
# [| vega) uanitiy to Pate Over No @! Persans [_] 8 te Owner Cover (Pisaee give detals of Momtnatton) C) PA tw Unnamed Passenger Sum Insured Bs,
# ronimocosmsvore = CT TT ETT ETT PET [off [Tee T) tate |
# On CLA
# tg ams era TT PEt rir rl eee — |
# [_* Aop-ncousy DETIEs, __. ar Oe,
# CJ Oepreclation Relmumsenent xr Car Only) a Cover tar Consumables (Pvt Car only) C) Engine quand (Pvt Car only) Remum To Invelee
# a Promckon of NCS (Cover avellanie 10 gravee! NEB upte SOB Onty as per elalotiay) CJ Beplenosomsleckoscisanacaaumeelmonlyy) C) Addiilonal road sida assistance (Pv Car only)
# CJ Loss of Personal Belongings (Pvt Car Only) Rs Cover for Key Replacement (Rul Car onty) Cj inconvenience Mowance (Pm Car Only) Rs,
# [__] Enhance PA Cover lor Insured (Ouner Orived / unnamed passengers / Pala Ortvers (Put Car only) sum Insured pee person Rs.
# LI} Hospital Cash Caver for insured (Owner Oriver) / unaamed passengers / Pald Odvers (Pl Car only) Rs. CQ EMI Protector (Private car only)
# CE Laveomeécanot, ( ameruncunse,_ (_] neasePunowmise _ __ __.
# tamcotfonesinwin [| | TTI ITILLLLII TTI ITIIIIIIIILI iam [TTT .
# wanes [J LT | Lil |_| [1 EET LT) somaccourn xo Coo LIILETT IJ @
# il | _ (SURES ORCEAREO VALUE, OVOP TIEVEICLE = __ a a. &
# ‘The (OY ol the vehicle ei badeemed the sum fnsuneditar te purpasa of es policy B willbe ued on Ore baste al the manuizctuers isted selling pice ol the brand andadusted ler Depactanen os per schedule betow 4
# [ Age all the Vediiele | Sol Daprecistion | Ago at the Vehlels % ol Ospreciation .
# Not Exceading Saonths ia } 5% Excooding 2 yoars bul nat exceeding 9 years we | SS
# Cnesadiag 6 montis bul nol Exesediag 1 year 18% Excovalng 3 years bu? nal exceeding 4 years 40% é
# Gwveeding | year bul aal exceeding 2 years 20% Exceeding 4 years bulnel exceeding S years SG% =
# [ VOUURARyOEMeMOE __ 8
# = = — =)
# Standard minimum deswetbis ts fis, 100/- lar a0 whesiers, Rs, 1000 for private cans with CC upto 1500 8 As. 2000)- ler private cars abave 1800 ce trom each ard ovary clam .
# PRIVATE CAR OEOUCTIBLE TWO WHEELER ogoUEr ]
# = oI : TLE &
# [_J Ste ain eeutie Pius As, 2500 | [LJ sta min dedueatbio Pie ——T ms, S00] So
# JL] Sié min éeduetle Plus — —_ Rs 5000 | (_] St min decuctte Plus ~ As, 750 | Ss
# [J Sid cnt cecuctibte Pius Rs. 7300 | (fe. - = 2
# (Co std min Gedetiite Pius = |_| Sis win deuce Pus Re todo]
# eee 2 _ tL Ris 98000 || Sto min dedvetiate Plus asiseo | &
# MES Giicarcecnelolcn gins As, 3000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Corgoraie & Aegistered Olkee Nava), 301, Junction al Western Exaress Highway & Anéhert - Kuda Read, Aadherl (East, Mumbai» 100 069,
#
# @-

# %%
img2 = pytesseract.image_to_string(gray)
print(img2)

# %%
img2 = pytesseract.image_to_string(thresh)
print(img2)
# Out:
# MELBIN
# MARTIN
